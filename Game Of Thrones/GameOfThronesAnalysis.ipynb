# %% [markdown]
# GAME OF THRONES!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS

# %%
battles = pd.read_csv("battles.csv")
deaths = pd.read_csv("character-deaths.csv")
predictions = pd.read_csv("character-predictions.csv")

# %%
battles.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# 1        NaN        NaN  Baratheon  ...         1.0            0.0
# 2        NaN        NaN      Tully  ...         0.0            1.0
# 3        NaN        NaN  Lannister  ...         1.0            1.0
# 4        NaN        NaN  Lannister  ...         1.0            1.0
#
#    attacker_size defender_size  \
# 0        15000.0        4000.0
# 1            NaN         120.0
# 2        15000.0       10000.0
# 3        18000.0       20000.0
# 4         1875.0        6000.0
#
#                                   attacker_commander  \
# 0                                    Jaime Lannister
# 1                                     Gregor Clegane
# 2                       Jaime Lannister, Andros Brax
# 3  Roose Bolton, Wylis Manderly, Medger Cerwyn, H...
# 4                          Robb Stark, Brynden Tully
#
#                                   defender_commander  summer         location  \
# 0                               Clement Piper, Vance     1.0     Golden Tooth
# 1                                   Beric Dondarrion     1.0    Mummer's Ford
# 2                      Edmure Tully, Tytos Blackwood     1.0         Riverrun
# 3  Tywin Lannister, Gregor Clegane, Kevan Lannist...     1.0       Green Fork
# 4                                    Jaime Lannister     1.0  Whispering Wood
#
#             region note
# 0  The Westerlands  NaN
# 1   The Riverlands  NaN
# 2   The Riverlands  NaN
# 3   The Riverlands  NaN
# 4   The Riverlands  NaN
#
# [5 rows x 25 columns]

# %%
deaths.head()
# Out:
#                       Name      Allegiances  Death Year  Book of Death  \
# 0           Addam Marbrand        Lannister         NaN            NaN
# 1  Aegon Frey (Jinglebell)              NaN       299.0            3.0
# 2          Aegon Targaryen  House Targaryen         NaN            NaN
# 3            Adrack Humble    House Greyjoy       300.0            5.0
# 4           Aemon Costayne        Lannister         NaN            NaN
#
#    Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0            NaN                56.0       1         1    1    1    1    1
# 1           51.0                49.0       1         1    0    0    1    0
# 2            NaN                 5.0       1         1    0    0    0    0
# 3           20.0                20.0       1         1    0    0    0    0
# 4            NaN                 NaN       1         1    0    0    1    0
#
#    DwD
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0

# %%
battles.tail()
# Out:
#                            name  year  battle_number  \
# 33  Second Seige of Storm's End   300             34
# 34         Siege of Dragonstone   300             35
# 35            Siege of Riverrun   300             36
# 36           Siege of Raventree   300             37
# 37          Siege of Winterfell   300             38
#
#                attacker_king             defender_king attacker_1 attacker_2  \
# 33  Joffrey/Tommen Baratheon         Stannis Baratheon  Baratheon        NaN
# 34  Joffrey/Tommen Baratheon         Stannis Baratheon  Baratheon        NaN
# 35  Joffrey/Tommen Baratheon                Robb Stark  Lannister       Frey
# 36  Joffrey/Tommen Baratheon                Robb Stark    Bracken  Lannister
# 37         Stannis Baratheon  Joffrey/Tommen Baratheon  Baratheon   Karstark
#
#    attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 33        NaN        NaN  Baratheon  ...         0.0            0.0
# 34        NaN        NaN  Baratheon  ...         0.0            0.0
# 35        NaN        NaN      Tully  ...         0.0            0.0
# 36        NaN        NaN  Blackwood  ...         0.0            1.0
# 37    Mormont     Glover     Bolton  ...         NaN            NaN
#
#     attacker_size defender_size                           attacker_commander  \
# 33            NaN         200.0                    Mace Tyrell, Mathis Rowan
# 34         2000.0           NaN                 Loras Tyrell, Raxter Redwyne
# 35         3000.0           NaN  Daven Lannister, Ryman Fey, Jaime Lannister
# 36         1500.0           NaN               Jonos Bracken, Jaime Lannister
# 37         5000.0        8000.0                            Stannis Baratheon
#
#     defender_commander  summer     location          region note
# 33     Gilbert Farring     0.0  Storm's End  The Stormlands  NaN
# 34       Rolland Storm     0.0  Dragonstone  The Stormlands  NaN
# 35       Brynden Tully     0.0     Riverrun  The Riverlands  NaN
# 36     Tytos Blackwood     0.0    Raventree  The Riverlands  NaN
# 37        Roose Bolton     0.0   Winterfell       The North  NaN
#
# [5 rows x 25 columns]

# %%
deaths.tail()
# Out:
#                   Name Allegiances  Death Year  Book of Death  Death Chapter  \
# 912              Zollo         NaN         NaN            NaN            NaN
# 913  Yurkhaz zo Yunzak         NaN       300.0            5.0           59.0
# 914   Yezzan Zo Qaggaz         NaN       300.0            5.0           57.0
# 915   Torwynd the Tame    Wildling       300.0            5.0           73.0
# 916      Talbert Serry      Tyrell       300.0            4.0           29.0
#
#      Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  DwD
# 912                21.0       1         0    0    0    1    0    0
# 913                47.0       1         0    0    0    0    0    1
# 914                25.0       1         1    0    0    0    0    1
# 915                73.0       1         0    0    0    1    0    0
# 916                29.0       1         1    0    0    0    1    0

# %%
battles.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
deaths.columns
# Out:
# Index(['Name', 'Allegiances', 'Death Year', 'Book of Death', 'Death Chapter',
#        'Book Intro Chapter', 'Gender', 'Nobility', 'GoT', 'CoK', 'SoS', 'FfC',
#        'DwD'],
#       dtype='object')

# %%
battles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                38 non-null     object
#  1   year                38 non-null     int64
#  2   battle_number       38 non-null     int64
#  3   attacker_king       36 non-null     object
#  4   defender_king       35 non-null     object
#  5   attacker_1          38 non-null     object
#  6   attacker_2          10 non-null     object
#  7   attacker_3          3 non-null      object
#  8   attacker_4          2 non-null      object
#  9   defender_1          37 non-null     object
#  10  defender_2          2 non-null      object
#  11  defender_3          0 non-null      float64
#  12  defender_4          0 non-null      float64
#  13  attacker_outcome    37 non-null     object
#  14  battle_type         37 non-null     object
#  15  major_death         37 non-null     float64
#  16  major_capture       37 non-null     float64
#  17  attacker_size       24 non-null     float64
#  18  defender_size       19 non-null     float64
#  19  attacker_commander  37 non-null     object
#  20  defender_commander  28 non-null     object
#  21  summer              37 non-null     float64
#  22  location            37 non-null     object
#  23  region              38 non-null     object
#  24  note                5 non-null      object
# dtypes: float64(7), int64(2), object(16)
# memory usage: 7.6+ KB

# %%
chosen_columns_battles =['name', 'year', 'battle_number', 'attacker_king', 'defender_king','attacker_outcome',
       'battle_type', 'major_death', 'major_capture', 'attacker_size',
       'defender_size', 'attacker_commander', 'defender_commander', 'summer',
       'location', 'region']
df_battles = pd.DataFrame(battles, columns = chosen_columns_battles)
df_battles.set_index('name', inplace=True)
df_battles.head()
# Out:
#                                year  battle_number             attacker_king  \
# name
# Battle of the Golden Tooth      298              1  Joffrey/Tommen Baratheon
# Battle at the Mummer's Ford     298              2  Joffrey/Tommen Baratheon
# Battle of Riverrun              298              3  Joffrey/Tommen Baratheon
# Battle of the Green Fork        298              4                Robb Stark
# Battle of the Whispering Wood   298              5                Robb Stark
#
#                                           defender_king attacker_outcome  \
# name
# Battle of the Golden Tooth                   Robb Stark              win
# Battle at the Mummer's Ford                  Robb Stark              win
# Battle of Riverrun                           Robb Stark              win
# Battle of the Green Fork       Joffrey/Tommen Baratheon             loss
# Battle of the Whispering Wood  Joffrey/Tommen Baratheon              win
#
#                                   battle_type  major_death  major_capture  \
# name
# Battle of the Golden Tooth     pitched battle          1.0            0.0
# Battle at the Mummer's Ford            ambush          1.0            0.0
# Battle of Riverrun             pitched battle          0.0            1.0
# Battle of the Green Fork       pitched battle          1.0            1.0
# Battle of the Whispering Wood          ambush          1.0            1.0
#
#                                attacker_size  defender_size  \
# name
# Battle of the Golden Tooth           15000.0         4000.0
# Battle at the Mummer's Ford              NaN          120.0
# Battle of Riverrun                   15000.0        10000.0
# Battle of the Green Fork             18000.0        20000.0
# Battle of the Whispering Wood         1875.0         6000.0
#
#                                                               attacker_commander  \
# name
# Battle of the Golden Tooth                                       Jaime Lannister
# Battle at the Mummer's Ford                                       Gregor Clegane
# Battle of Riverrun                                  Jaime Lannister, Andros Brax
# Battle of the Green Fork       Roose Bolton, Wylis Manderly, Medger Cerwyn, H...
# Battle of the Whispering Wood                          Robb Stark, Brynden Tully
#
#                                                               defender_commander  \
# name
# Battle of the Golden Tooth                                  Clement Piper, Vance
# Battle at the Mummer's Ford                                     Beric Dondarrion
# Battle of Riverrun                                 Edmure Tully, Tytos Blackwood
# Battle of the Green Fork       Tywin Lannister, Gregor Clegane, Kevan Lannist...
# Battle of the Whispering Wood                                    Jaime Lannister
#
#                                summer         location           region
# name
# Battle of the Golden Tooth        1.0     Golden Tooth  The Westerlands
# Battle at the Mummer's Ford       1.0    Mummer's Ford   The Riverlands
# Battle of Riverrun                1.0         Riverrun   The Riverlands
# Battle of the Green Fork          1.0       Green Fork   The Riverlands
# Battle of the Whispering Wood     1.0  Whispering Wood   The Riverlands

# %% [markdown]
# I was curious who were the most aggressive kings.

# %%
df_battles['attacker_king'].value_counts().head()
# Out:
# attacker_king
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# Name: count, dtype: int64

# %% [markdown]
# I was also curious about the most defensive king. Apparently, joffrey was really into fighting. Which is strange, considering Joffrey is... Joffrey.

# %%
df_battles['defender_king'].value_counts().head()
# Out:
# defender_king
# Robb Stark                  14
# Joffrey/Tommen Baratheon    13
# Balon/Euron Greyjoy          4
# Stannis Baratheon            2
# Renly Baratheon              1
# Name: count, dtype: int64

# %% [markdown]
# What was the type of warfare that was common in Westeros. I thought it would be ambush battles, so I checked it.

# %%
df_battles['battle_type'].value_counts().head()
# Out:
# battle_type
# pitched battle    14
# siege             11
# ambush            10
# razing             2
# Name: count, dtype: int64

# %% [markdown]
# Oluşturduğumuz dataframemizde en çok kullanıla savaş türünü ilk beş tanesini listelettirdik.

# %%
df_battles['attacker_commander'].value_counts().head()
# Out:
# attacker_commander
# Gregor Clegane                      4
# Theon Greyjoy                       2
# Robb Stark, Brynden Tully           2
# Euron Greyjoy, Victarion Greyjoy    2
# Rorge                               1
# Name: count, dtype: int64

# %% [markdown]
# And the most aggressive commander out of all was *dumbroll* Clegane! No surprise.

# %%
df_battles['defender_commander'].value_counts().head()
# Out:
# defender_commander
# Clement Piper, Vance    1
# Beric Dondarrion        1
# Tytos Blackwood         1
# Brynden Tully           1
# Rolland Storm           1
# Name: count, dtype: int64

# %% [markdown]
# And the commanders that did most of defences. Apparently, westerosi culture deems defending, WEAK.

# %%
df_battles['summer'].value_counts().head()
# Out:
# summer
# 1.0    26
# 0.0    11
# Name: count, dtype: int64

# %% [markdown]
# As winter and summer is a big deal in the books, I wondered, how mant battles occured in summer and winter(1 = summer, 0 = winter). I was surprised that people fought in winter.

# %%
df_battles['location'].value_counts().head()
# Out:
# location
# Riverrun       3
# Winterfell     3
# Storm's End    2
# Harrenhal      2
# Darry          2
# Name: count, dtype: int64

# %%
df_battles['region'].value_counts().head()
# Out:
# region
# The Riverlands     17
# The North          10
# The Westerlands     3
# The Stormlands      3
# The Crownlands      2
# Name: count, dtype: int64

# %% [markdown]
# And the province with most battles are, no surprise, Riverrun and Winterfell.

# %%
df_battles['attacker_size'].value_counts().head()
# Out:
# attacker_size
# 6000.0     3
# 15000.0    2
# 3000.0     2
# 5000.0     2
# 1000.0     1
# Name: count, dtype: int64

# %%
df_battles['defender_size'].value_counts().head()
# Out:
# defender_size
# 10000.0    3
# 20000.0    2
# 6000.0     2
# 200.0      2
# 4000.0     1
# Name: count, dtype: int64

# %%
deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 917 entries, 0 to 916
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                917 non-null    object
#  1   Allegiances         664 non-null    object
#  2   Death Year          305 non-null    float64
#  3   Book of Death       307 non-null    float64
#  4   Death Chapter       299 non-null    float64
#  5   Book Intro Chapter  905 non-null    float64
#  6   Gender              917 non-null    int64
#  7   Nobility            917 non-null    int64
#  8   GoT                 917 non-null    int64
#  9   CoK                 917 non-null    int64
#  10  SoS                 917 non-null    int64
#  11  FfC                 917 non-null    int64
#  12  DwD                 917 non-null    int64
# dtypes: float64(4), int64(7), object(2)
# memory usage: 93.3+ KB

# %%
chosen_columns_deaths =['Name', 'Allegiances', 'Death Year', 'Book of Death', 'Death Chapter',
       'Book Intro Chapter', 'Gender', 'Nobility', 'GoT', 'CoK', 'SoS', 'FfC',
       'DwD']
df_deaths = pd.DataFrame(deaths, columns = chosen_columns_deaths)
df_deaths.set_index('Name', inplace=True)
df_deaths.head()
# Out:
#                              Allegiances  Death Year  Book of Death  \
# Name
# Addam Marbrand                 Lannister         NaN            NaN
# Aegon Frey (Jinglebell)              NaN       299.0            3.0
# Aegon Targaryen          House Targaryen         NaN            NaN
# Adrack Humble              House Greyjoy       300.0            5.0
# Aemon Costayne                 Lannister         NaN            NaN
#
#                          Death Chapter  Book Intro Chapter  Gender  Nobility  \
# Name
# Addam Marbrand                     NaN                56.0       1         1
# Aegon Frey (Jinglebell)           51.0                49.0       1         1
# Aegon Targaryen                    NaN                 5.0       1         1
# Adrack Humble                     20.0                20.0       1         1
# Aemon Costayne                     NaN                 NaN       1         1
#
#                          GoT  CoK  SoS  FfC  DwD
# Name
# Addam Marbrand             1    1    1    1    0
# Aegon Frey (Jinglebell)    0    0    1    0    0
# Aegon Targaryen            0    0    0    0    1
# Adrack Humble              0    0    0    0    1
# Aemon Costayne             0    0    1    0    0

# %%
battles.describe()
# Out:
#              year  battle_number  defender_3  defender_4  major_death  \
# count   38.000000      38.000000         0.0         0.0    37.000000
# mean   299.105263      19.500000         NaN         NaN     0.351351
# std      0.689280      11.113055         NaN         NaN     0.483978
# min    298.000000       1.000000         NaN         NaN     0.000000
# 25%    299.000000      10.250000         NaN         NaN     0.000000
# 50%    299.000000      19.500000         NaN         NaN     0.000000
# 75%    300.000000      28.750000         NaN         NaN     1.000000
# max    300.000000      38.000000         NaN         NaN     1.000000
#
#        major_capture  attacker_size  defender_size     summer
# count      37.000000      24.000000      19.000000  37.000000
# mean        0.297297    9942.541667    6428.157895   0.702703
# std         0.463373   20283.092065    6225.182106   0.463373
# min         0.000000      20.000000     100.000000   0.000000
# 25%         0.000000    1375.000000    1070.000000   0.000000
# 50%         0.000000    4000.000000    6000.000000   1.000000
# 75%         1.000000    8250.000000   10000.000000   1.000000
# max         1.000000  100000.000000   20000.000000   1.000000

# %%
deaths.describe()
# Out:
#        Death Year  Book of Death  Death Chapter  Book Intro Chapter  \
# count  305.000000     307.000000     299.000000          905.000000
# mean   299.157377       2.928339      40.070234           28.861878
# std      0.703483       1.326482      20.470270           20.165788
# min    297.000000       1.000000       0.000000            0.000000
# 25%    299.000000       2.000000      25.500000           11.000000
# 50%    299.000000       3.000000      39.000000           27.000000
# 75%    300.000000       4.000000      57.000000           43.000000
# max    300.000000       5.000000      80.000000           80.000000
#
#            Gender    Nobility         GoT         CoK         SoS         FfC  \
# count  917.000000  917.000000  917.000000  917.000000  917.000000  917.000000
# mean     0.828790    0.468920    0.272628    0.353326    0.424209    0.272628
# std      0.376898    0.499305    0.445554    0.478264    0.494492    0.445554
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               DwD
# count  917.000000
# mean     0.284624
# std      0.451481
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %%
predictions.describe()
# Out:
#               S.No       actual         pred        alive         plod  \
# count  1946.000000  1946.000000  1946.000000  1946.000000  1946.000000
# mean    973.500000     0.745632     0.687050     0.634470     0.365530
# std     561.906131     0.435617     0.463813     0.312637     0.312637
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%     487.250000     0.000000     0.000000     0.391250     0.101000
# 50%     973.500000     1.000000     1.000000     0.735500     0.264500
# 75%    1459.750000     1.000000     1.000000     0.899000     0.608750
# max    1946.000000     1.000000     1.000000     1.000000     1.000000
#
#               male    dateOfBirth    DateoFdeath        book1        book2  \
# count  1946.000000     433.000000     444.000000  1946.000000  1946.000000
# mean      0.619219    1577.364896    2950.193694     0.198356     0.374615
# std       0.485704   19565.414460   28192.245529     0.398864     0.484148
# min       0.000000     -28.000000       0.000000     0.000000     0.000000
# 25%       0.000000     240.000000     282.000000     0.000000     0.000000
# 50%       1.000000     268.000000     299.000000     0.000000     0.000000
# 75%       1.000000     285.000000     299.000000     0.000000     1.000000
# max       1.000000  298299.000000  298299.000000     1.000000     1.000000
#
#        ...  isAliveHeir  isAliveSpouse    isMarried      isNoble  \
# count  ...    23.000000     276.000000  1946.000000  1946.000000
# mean   ...     0.652174       0.778986     0.141829     0.460946
# std    ...     0.486985       0.415684     0.348965     0.498601
# min    ...     0.000000       0.000000     0.000000     0.000000
# 25%    ...     0.000000       1.000000     0.000000     0.000000
# 50%    ...     1.000000       1.000000     0.000000     0.000000
# 75%    ...     1.000000       1.000000     0.000000     1.000000
# max    ...     1.000000       1.000000     1.000000     1.000000
#
#                  age  numDeadRelations  boolDeadRelations    isPopular  \
# count     433.000000       1946.000000        1946.000000  1946.000000
# mean    -1293.563510          0.305755           0.074512     0.059096
# std     19564.340993          1.383910           0.262669     0.235864
# min   -298001.000000          0.000000           0.000000     0.000000
# 25%        18.000000          0.000000           0.000000     0.000000
# 50%        27.000000          0.000000           0.000000     0.000000
# 75%        50.000000          0.000000           0.000000     0.000000
# max       100.000000         15.000000           1.000000     1.000000
#
#         popularity      isAlive
# count  1946.000000  1946.000000
# mean      0.089584     0.745632
# std       0.160568     0.435617
# min       0.000000     0.000000
# 25%       0.013378     0.000000
# 50%       0.033445     1.000000
# 75%       0.086957     1.000000
# max       1.000000     1.000000
#
# [8 rows x 25 columns]

# %%
sns.countplot(deaths['Allegiances'])
plt.xticks(rotation=90)  # Use lowercase 'rotation'
plt.title('Death by Allegiances')
plt.show()

# %%
sns.countplot(deaths['Gender'])
plt.title('Death by Gender')
plt.xticks(np.arange(2),('Woman','Man'))
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.title('Attacker Kings')
plt.subplot(2,1,1)
sns.countplot(x='attacker_king',data = battles)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,1,2)
sns.countplot(x='defender_king',data = battles)
plt.show()

# %%
sns.countplot(hue= battles['battle_type'],x=battles['attacker_king'],palette = 'Set3')
plt.title('Battle type by Aggressive Kings')
plt.legend(loc = 'upper right')
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(x='summer',data = battles)
plt.title('Wars by Season')
plt.xticks(np.arange(2),('Winter','Summer'))
plt.show()

# %%
sns.countplot(x='region', data = battles)
plt.title('Battles by Region')
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(x='region',hue='attacker_king', data = battles)
plt.title('Which King Attacked Where')
plt.xticks(rotation = 90)
plt.legend(loc = 'upper right')
plt.show()

# %%
deaths.head()
# Out:
#                       Name      Allegiances  Death Year  Book of Death  \
# 0           Addam Marbrand        Lannister         NaN            NaN
# 1  Aegon Frey (Jinglebell)              NaN       299.0            3.0
# 2          Aegon Targaryen  House Targaryen         NaN            NaN
# 3            Adrack Humble    House Greyjoy       300.0            5.0
# 4           Aemon Costayne        Lannister         NaN            NaN
#
#    Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0            NaN                56.0       1         1    1    1    1    1
# 1           51.0                49.0       1         1    0    0    1    0
# 2            NaN                 5.0       1         1    0    0    0    0
# 3           20.0                20.0       1         1    0    0    0    0
# 4            NaN                 NaN       1         1    0    0    1    0
#
#    DwD
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0

# %%
deaths.hist()
plt.show()

# %%
# Select only numeric columns
numeric_deaths = deaths.select_dtypes(include=[float, int])

# Calculate the correlation matrix
co = numeric_deaths.corr()

# Create the heatmap
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(co, annot=True, linewidths=1.0)
plt.show()

# %%
battles.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1 ...  major_death  major_capture  \
# 0        NaN        NaN      Tully ...          1.0            0.0
# 1        NaN        NaN  Baratheon ...          1.0            0.0
# 2        NaN        NaN      Tully ...          0.0            1.0
# 3        NaN        NaN  Lannister ...          1.0            1.0
# 4        NaN        NaN  Lannister ...          1.0            1.0
#
#    attacker_size defender_size  \
# 0        15000.0        4000.0
# 1            NaN         120.0
# 2        15000.0       10000.0
# 3        18000.0       20000.0
# 4         1875.0        6000.0
#
#                                   attacker_commander  \
# 0                                    Jaime Lannister
# 1                                     Gregor Clegane
# 2                       Jaime Lannister, Andros Brax
# 3  Roose Bolton, Wylis Manderly, Medger Cerwyn, H...
# 4                          Robb Stark, Brynden Tully
#
#                                   defender_commander  summer         location  \
# 0                               Clement Piper, Vance     1.0     Golden Tooth
# 1                                   Beric Dondarrion     1.0    Mummer's Ford
# 2                      Edmure Tully, Tytos Blackwood     1.0         Riverrun
# 3  Tywin Lannister, Gregor Clegane, Kevan Lannist...     1.0       Green Fork
# 4                                    Jaime Lannister     1.0  Whispering Wood
#
#             region note
# 0  The Westerlands  NaN
# 1   The Riverlands  NaN
# 2   The Riverlands  NaN
# 3   The Riverlands  NaN
# 4   The Riverlands  NaN
#
# [5 rows x 25 columns]

# %%
battles.hist()
plt.show()

# %%
co = battles.corr()
sns.heatmap(co, annot=True, linewidths=1.0)

# %%
most_pop_genres = battles['defender_commander'].str.cat(sep=', ').split(', ')
most_pop_genres = pd.Series(most_pop_genres).value_counts() 
graph = most_pop_genres.plot.bar()
graph.set_title("Most Defensive Kings", fontsize=18, fontweight='bold')
graph.set_xlabel("Battle Counts", fontsize=16)
graph.set_ylabel("Commander Lists", fontsize=16)
graph.set_xlim(right=10)
graph.legend(['Commander'], loc = "upper right")

# %%
most_pop_genres = battles['attacker_commander'].str.cat(sep=', ').split(', ')
most_pop_genres = pd.Series(most_pop_genres).value_counts(ascending=False) 
graph = most_pop_genres.plot.bar()
graph.set_title("Most Aggressive Kings", fontsize=18, fontweight='bold')
graph.set_xlabel("Battle Counts", fontsize=16)
graph.set_ylabel("Commander List", fontsize=16)
graph.set_xlim(right=10)
graph.legend(['Commander'], loc = "upper right")

# %%
df_battles.head()
# Out:
#                                year  battle_number             attacker_king  \
# name
# Battle of the Golden Tooth      298              1  Joffrey/Tommen Baratheon
# Battle at the Mummer's Ford     298              2  Joffrey/Tommen Baratheon
# Battle of Riverrun              298              3  Joffrey/Tommen Baratheon
# Battle of the Green Fork        298              4                Robb Stark
# Battle of the Whispering Wood   298              5                Robb Stark
#
#                                           defender_king attacker_outcome  \
# name
# Battle of the Golden Tooth                   Robb Stark              win
# Battle at the Mummer's Ford                  Robb Stark              win
# Battle of Riverrun                           Robb Stark              win
# Battle of the Green Fork       Joffrey/Tommen Baratheon             loss
# Battle of the Whispering Wood  Joffrey/Tommen Baratheon              win
#
#                                   battle_type  major_death  major_capture  \
# name
# Battle of the Golden Tooth     pitched battle          1.0            0.0
# Battle at the Mummer's Ford            ambush          1.0            0.0
# Battle of Riverrun             pitched battle          0.0            1.0
# Battle of the Green Fork       pitched battle          1.0            1.0
# Battle of the Whispering Wood          ambush          1.0            1.0
#
#                                attacker_size  defender_size  \
# name
# Battle of the Golden Tooth           15000.0         4000.0
# Battle at the Mummer's Ford              NaN          120.0
# Battle of Riverrun                   15000.0        10000.0
# Battle of the Green Fork             18000.0        20000.0
# Battle of the Whispering Wood         1875.0         6000.0
#
#                                                               attacker_commander  \
# name
# Battle of the Golden Tooth                                       Jaime Lannister
# Battle at the Mummer's Ford                                       Gregor Clegane
# Battle of Riverrun                                  Jaime Lannister, Andros Brax
# Battle of the Green Fork       Roose Bolton, Wylis Manderly, Medger Cerwyn, H...
# Battle of the Whispering Wood                          Robb Stark, Brynden Tully
#
#                                                               defender_commander  \
# name
# Battle of the Golden Tooth                                  Clement Piper, Vance
# Battle at the Mummer's Ford                                     Beric Dondarrion
# Battle of Riverrun                                 Edmure Tully, Tytos Blackwood
# Battle of the Green Fork       Tywin Lannister, Gregor Clegane, Kevan Lannist...
# Battle of the Whispering Wood                                    Jaime Lannister
#
#                                summer         location           region
# name
# Battle of the Golden Tooth        1.0     Golden Tooth  The Westerlands
# Battle at the Mummer's Ford       1.0    Mummer's Ford   The Riverlands
# Battle of Riverrun                1.0         Riverrun   The Riverlands
# Battle of the Green Fork          1.0       Green Fork   The Riverlands
# Battle of the Whispering Wood     1.0  Whispering Wood   The Riverlands

# %%
#region,location,defender_commander,attacker_commander
plt.figure(figsize = (30,30))
stopwords = set(STOPWORDS)
wordcloud = WordCloud(
                          background_color='black',
                          stopwords=stopwords,
                          max_words=1200,
                          max_font_size=120, 
                          random_state=42
                         ).generate(str(df_battles['region']))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.title("WORD CLOUD - TAGS")
plt.axis('off')
plt.show()

plt.figure(figsize = (30,30))
stopwords = set(STOPWORDS)
wordcloud = WordCloud(
                          background_color='Red',
                          stopwords=stopwords,
                          max_words=1200,
                          max_font_size=120, 
                          random_state=42
                         ).generate(str(df_battles['location']))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.title("WORD CLOUD - TAGS")
plt.axis('off')
plt.show()

plt.figure(figsize = (30,30))
stopwords = set(STOPWORDS)
wordcloud = WordCloud(
                          background_color='Purple',
                          stopwords=stopwords,
                          max_words=1200,
                          max_font_size=120, 
                          random_state=42
                         ).generate(str(df_battles['defender_commander']))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.title("WORD CLOUD - TAGS")
plt.axis('off')
plt.show()

plt.figure(figsize = (30,30))
stopwords = set(STOPWORDS)
wordcloud = WordCloud(
                          background_color='Yellow',
                          stopwords=stopwords,
                          max_words=1200,
                          max_font_size=120, 
                          random_state=42
                         ).generate(str(df_battles['attacker_commander']))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.title("WORD CLOUD - TAGS")
plt.axis('off')
plt.show()

plt.figure(figsize = (30,30))
stopwords = set(STOPWORDS)
wordcloud = WordCloud(
                          background_color='Green',
                          stopwords=stopwords,
                          max_words=1200,
                          max_font_size=120, 
                          random_state=42
                         ).generate(str(df_battles['attacker_king']))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.title("WORD CLOUD - TAGS")
plt.axis('off')
plt.show()

plt.figure(figsize = (30,30))
stopwords = set(STOPWORDS)
wordcloud = WordCloud(
                          background_color='White',
                          stopwords=stopwords,
                          max_words=1200,
                          max_font_size=120, 
                          random_state=42
                         ).generate(str(df_battles['defender_king']))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.title("WORD CLOUD - TAGS")
plt.axis('off')
plt.show()

plt.figure(figsize = (30,30))
stopwords = set(STOPWORDS)
wordcloud = WordCloud(
                          background_color='Grey',
                          stopwords=stopwords,
                          max_words=1200,
                          max_font_size=120, 
                          random_state=42
                         ).generate(str(df_battles['battle_type']))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.title("WORD CLOUD - TAGS")
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x15a3b5460>
# <wordcloud.wordcloud.WordCloud object at 0x15a340470>
# <wordcloud.wordcloud.WordCloud object at 0x14eeb9c70>
# <wordcloud.wordcloud.WordCloud object at 0x14c6a05f0>
# <wordcloud.wordcloud.WordCloud object at 0x14efc9130>
# <wordcloud.wordcloud.WordCloud object at 0x14eeb8b60>
# <wordcloud.wordcloud.WordCloud object at 0x15a343080>

# %% [markdown]
# Prepare yourselves for unclean datas, for the night is dark, and full of terrors.
